# %% [markdown]
# <h1> 1. Exploring natality dataset </h1>
#
# This notebook illustrates:
# <ol>
# <li> Exploring a BigQuery dataset using Datalab
# </ol>

# %%
# change these to try this notebook out
BUCKET = 'cloud-training-demos-ml'   # CHANGE this to a globally unique value. Your project name is a good option to try.
PROJECT = 'cloud-training-demos'     # CHANGE this to your project name
REGION = 'us-central1'               # CHANGE this to one of the regions supported by Cloud ML Engine https://cloud.google.com/ml-engine/docs/tensorflow/regions

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %%bash
# if ! gsutil ls | grep -q gs://${BUCKET}/; then
#   gsutil mb -l ${REGION} gs://${BUCKET}
# fi
# Out:
# Creating gs://cloud-training-demos-ml/...
# ServiceException: 409 Bucket cloud-training-demos-ml already exists.

# %% [markdown]
# <h2> Explore data </h2>
#
# The data is natality data (record of births in the US). My goal is to predict the baby's weight given a number of factors about the pregnancy and the baby's mother.  Later, we will want to split the data into training and eval datasets. The hash of the year-month will be used for that -- this way, twins born on the same day won't end up in different cuts of the data.

# %%
# Create SQL query using natality data after the year 2000
query = """
SELECT
  weight_pounds,
  is_male,
  mother_age,
  plurality,
  gestation_weeks,
  ABS(FARM_FINGERPRINT(CONCAT(CAST(YEAR AS STRING), CAST(month AS STRING)))) AS hashmonth
FROM
  publicdata.samples.natality
WHERE year > 2000
"""

# %%
# Call BigQuery and examine in dataframe
import google.datalab.bigquery as bq
df = bq.Query(query + " LIMIT 100").execute().result().to_dataframe()
df.head()
# Out:
#    weight_pounds  is_male  mother_age  plurality  gestation_weeks  \
# 0       7.063611     True          32          1             37.0
# 1       4.687028     True          30          3             33.0
# 2       7.561856     True          20          1             39.0
# 3       7.561856     True          31          1             37.0
# 4       7.312733     True          32          1             40.0
#
#              hashmonth
# 0  7108882242435606404
# 1  7170969733900686954
# 2  6392072535155213407
# 3  2126480030009879160
# 4  3408502330831153141

# %% [markdown]
# ## Lab Task #1
# Using the above code as an example, write a query to find the unique values for each of the columns and the count of those values for babies born after the year 2000.
# For example, we want to get these values:
# <pre>
# is_male	num_babies	avg_wt
# False	16245054	7.104715
#  True	17026860	7.349797
# </pre>
# This is important to ensure that we have enough examples of each data value, and to verify our hunch that the parameter has predictive value.
#
# Hint (highlight to see): <p style='color:white'>Use COUNT(), AVG() and GROUP BY. For example:
# <pre style='color:white'>
# SELECT
#   is_male,
#   COUNT(1) AS num_babies,
#   AVG(weight_pounds) AS avg_wt
# FROM
#   publicdata.samples.natality
# WHERE
#   year > 2000
# GROUP BY
#   is_male
# </pre>
# </p>

# %%
#creating query to extract unique and count for columns for babies born after 2000
def distinct_values_by_col(col_name):
  sql = """
  SELECT
  {0},
  COUNT(1) AS num_babies,
  AVG(weight_pounds) AS av_wt
FROM
  publicdata.samples.natality
WHERE
  year > 2000
GROUP BY
  {0}
  """.format(col_name)
  return bq.Query(sql).execute().result().to_dataframe()

# %%
df = distinct_values_by_col('is_male')
df.plot(x = "is_male",y = "num_babies", kind="bar")
df.plot(x = "is_male", y = "av_wt", kind="bar")
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#mother's age vs baby weight and count
df = distinct_values_by_col("mother_age")
df = df.sort_values("mother_age")
df.plot(x = "mother_age", y = "num_babies");
df.plot(x = "mother_age", y = "av_wt");
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#pluraity wrt num_babies and weight
df = distinct_values_by_col("plurality")
df= df.sort_values("plurality")
df.plot(x = "plurality" , y = "num_babies", kind = 'bar');
df.plot(x = "plurality" , y = "num_babies", logy = True,kind = 'bar');
df.plot(x = "plurality" , y = "av_wt", kind = 'bar');
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#gestation period wrt num_babies and weight
df = distinct_values_by_col("gestation_weeks")
df = df.sort_values('gestation_weeks')
df.plot(x='gestation_weeks', y='num_babies', logy=True, kind='bar');
df.plot(x='gestation_weeks', y='av_wt', kind='bar');
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Lab Task #2
#
# Which factors seem to play a part in the baby's weight?
#
# <b>Bonus:</b> Draw graphs to illustrate your conclusions
#
# Hint (highlight to see): <p style='color:white'> The simplest way to plot is to use Pandas' built-in plotting capability
# <pre style='color:white'>
# import google.datalab.bigquery as bq
# df = bq.Query(query).execute().result().to_dataframe()
# df.plot(x='is_male', y='num_babies', logy=True, kind='bar');
# df.plot(x='is_male', y='avg_wt', kind='bar');
# </pre>

# %%
df = bq.Query(query + " LIMIT 10000").execute().result().to_dataframe()
df = df.sort_values("mother_age")
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(x = "mother_age", y = "weight_pounds")
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(x = "gestation_weeks", y = "weight_pounds")
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(x = "plurality", y = "weight_pounds")
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# conclusion Plurality and gestation weeks has high correlation with the label - weight_pounds and these are important factors according to
#the existing dataset

# %% [markdown]
# Copyright 2017-2018 Google Inc. Licensed under the Apache License, Version 2.0 (the "License"); you may not use this file except in compliance with the License. You may obtain a copy of the License at http://www.apache.org/licenses/LICENSE-2.0 Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License
